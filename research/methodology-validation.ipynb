# %% [markdown]
# # Methodology Validation — Rust vs Python
#
# **Used in:** M1+ (continuous regression check).
#
# **Goal:** for any input strip, the Rust engine output and the Python reference output must agree to a tight tolerance (1e-6 on variance, 1e-3 on the index value).
#
# **How:** dump a strip + computed BVOL from the Rust engine to JSON; load it here; recompute with Python; diff. Any disagreement is a Rust bug (or a methodology bug Python missed, in which case both get fixed).
#
# ## Plan
#
# 1. Load the Rust engine's debug dump (strip + intermediate values + final index).
# 2. Recompute end-to-end in Python.
# 3. Diff each stage: forward, K₀, strip composition, per-strike variance contributions, total variance, interpolation result, final BVOL.
# 4. Print first divergence + tolerance check.

# %% [markdown]
# ## 1. Imports

# %%
import json
from pathlib import Path

import numpy as np
import pandas as pd

# %% [markdown]
# ## 2. Load Rust engine dump

# %% [markdown]
# ## 3. Python recomputation

# %% [markdown]
# ## 4. Diff + tolerance report
